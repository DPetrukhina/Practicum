# %% [markdown]
# # Исследование причин возникновения убытков в компании, выпустившей приложение Procrastinate Pro+
#
# Цель исследования: выяснить факторы возникновения убытков в компании при вычислении маркетинговых показателей на основе данных о посещениях сайтов, заказах пользователей и данных о расходах компании.
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка их к анализу</a></span></li><li><span><a href="#Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчёта и анализа LTV, ROI, удержания и конверсии</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Распределение-пользователей-по-странам" data-toc-modified-id="Распределение-пользователей-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение пользователей по странам</a></span></li><li><span><a href="#Распределение-пользователей-по-устройствам" data-toc-modified-id="Распределение-пользователей-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Распределение пользователей по устройствам</a></span></li><li><span><a href="#Распределение-пользователей-по-каналам" data-toc-modified-id="Распределение-пользователей-по-каналам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Распределение пользователей по каналам</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы-на-маркетинг" data-toc-modified-id="Расходы-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расходы на маркетинг</a></span></li><li><span><a href="#Динамика-затрат" data-toc-modified-id="Динамика-затрат-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Динамика затрат</a></span></li><li><span><a href="#Стоимость-привлечения-одного-пользователя" data-toc-modified-id="Стоимость-привлечения-одного-пользователя-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Стоимость привлечения одного пользователя</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Окупаемость-рекламы" data-toc-modified-id="Окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Окупаемость-рекламы-по-странам" data-toc-modified-id="Окупаемость-рекламы-по-странам-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Окупаемость рекламы по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-по-каналам" data-toc-modified-id="Окупаемость-рекламы-по-каналам-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Окупаемость рекламы по каналам</a></span></li><li><span><a href="#Окупаемость-рекламы-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-по-устройствам-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Окупаемость рекламы по устройствам</a></span></li></ul></li><li><span><a href="#Конверсия-пользователей" data-toc-modified-id="Конверсия-пользователей-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Конверсия пользователей</a></span><ul class="toc-item"><li><span><a href="#Конверия-пользователей-по-устройствам" data-toc-modified-id="Конверия-пользователей-по-устройствам-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Конверия пользователей по устройствам</a></span></li><li><span><a href="#Конверсия-пользователей-по-странам" data-toc-modified-id="Конверсия-пользователей-по-странам-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Конверсия пользователей по странам</a></span></li><li><span><a href="#Конверсия-пользователей-по-каналам" data-toc-modified-id="Конверсия-пользователей-по-каналам-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Конверсия пользователей по каналам</a></span></li></ul></li><li><span><a href="#Удержание-пользователей" data-toc-modified-id="Удержание-пользователей-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Удержание пользователей</a></span><ul class="toc-item"><li><span><a href="#Удержание-пользователей-по-устройствам" data-toc-modified-id="Удержание-пользователей-по-устройствам-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Удержание пользователей по устройствам</a></span></li><li><span><a href="#Удержание-пользователей-по-странам" data-toc-modified-id="Удержание-пользователей-по-странам-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Удержание пользователей по странам</a></span></li><li><span><a href="#Удержание-пользователей-по-каналам" data-toc-modified-id="Удержание-пользователей-по-каналам-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Удержание пользователей по каналам</a></span></li></ul></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %%
# импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from datetime import date, datetime, timedelta
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %%
# загрузка данных
visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),  # журнал сессий
    pd.read_csv('/datasets/orders_info_short.csv'),  # покупки
    pd.read_csv('/datasets/costs_info_short.csv'),  # траты на рекламу
)
# обзор общей информации
visits.info()
orders.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# Исходя из информации о таблицах делаем вывод, что необходимо исправить некоторые типы данных, переименовать названия столбцов для удобства редактирования.

# %%
# переименование столбцов
visits.columns = ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']
orders.columns = ['user_id', 'event_dt', 'revenue']
costs.columns = ['dt', 'channel', 'costs']

# преобразование данных о времени
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_start'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# отобразим данные
display(visits.head(), orders.head(), costs.head())
# Out:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           session_end
# 0 2019-05-01 02:36:01
# 1 2019-05-01 04:46:31
# 2 2019-05-01 14:09:25
# 3 2019-05-01 00:29:59
# 4 2019-05-01 03:33:35
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# ...

# %% [markdown]
# Теперь таблицы имеют подходящий вид и контент для работы.

# %%
# изучим явные дубликаты
display(visits.duplicated().sum())
display(orders.duplicated().sum())
display(costs.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# Таким образом, удалось рассмотреть данные 3-ёх исходных таблиц. В результате предобработки были проверены типы данных и изменены некорректные, исправлена запись названий колонок таблиц для удобства анализа. Пропусков и дубликатов не обнаружено.

# %% [markdown]
# ## Функции для расчёта и анализа LTV, ROI, удержания и конверсии
#
# Создадим следующие функции:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %%
# функция для создания пользовательских профилей
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_costs'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_costs']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_costs'] = profiles['acquisition_costs'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_costs'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_costs': 'mean'})
            .rename(columns={'acquisition_costs': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# функция для сглаживания фрейма
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания
def plot_retention(retention, retention_history, horizon, window=14):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии
def plot_conversion(conversion, conversion_history, horizon, window=14):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=14):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# В результате были заданы функции для дальнейшего анализа.
#
# ## Исследовательский анализ данных
#
# ### Профили пользователей

# %%
profiles = get_profiles(visits, orders, costs) # создадим таблицу profiles
profiles.info() # выведем информацию о таблице
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150008 entries, 0 to 150007
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   user_id            150008 non-null  int64
#  1   first_ts           150008 non-null  datetime64[ns]
#  2   channel            150008 non-null  object
#  3   device             150008 non-null  object
#  4   region             150008 non-null  object
#  5   dt                 150008 non-null  object
#  6   month              150008 non-null  datetime64[ns]
#  7   payer              150008 non-null  bool
#  8   acquisition_costs  150008 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 10.4+ MB

# %%
profiles['dt'] = profiles['first_ts'].dt.date
profiles['dt'] = pd.to_datetime(profiles['dt'], format="%Y-%m-%d")
profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
profiles.info() # выведем информацию о таблице после исправления типов данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150008 entries, 0 to 150007
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   user_id            150008 non-null  int64
#  1   first_ts           150008 non-null  datetime64[ns]
#  2   channel            150008 non-null  object
#  3   device             150008 non-null  object
#  4   region             150008 non-null  object
#  5   dt                 150008 non-null  datetime64[ns]
#  6   month              150008 non-null  datetime64[ns]
#  7   payer              150008 non-null  bool
#  8   acquisition_costs  150008 non-null  float64
# dtypes: bool(1), datetime64[ns](3), float64(1), int64(1), object(3)
# memory usage: 10.4+ MB

# %%
profiles.head() # выведем данные первых 5 строк таблицы
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_costs
# 0 2019-05-01   True           1.088172
# 1 2019-07-01  False           1.107237
# 2 2019-10-01  False           0.000000
# 3 2019-08-01  False           0.988235
# 4 2019-10-01  False           0.230769

# %%
min_analysis_date = profiles['dt'].min()
observation_date = profiles['dt'].max() 
display(min_analysis_date)
display(observation_date)
# Out:
# Timestamp('2019-05-01 00:00:00')
# Timestamp('2019-10-27 00:00:00')

# %% [markdown]
# **Минимальная дата привлечения пользователей: 1 мая 2019 года.**
#
# **Максимальная дата привлечения пользователей: 27 октября 2019 года.**
#
# ### Распределение пользователей по странам

# %%
region_users = pd.DataFrame()
region_users['users_cnt'] = profiles.groupby('region')['user_id'].count()
region_users['payer_users_cnt'] = profiles.query('payer == True').groupby('region')['user_id'].count()
region_users['share'] = (region_users['payer_users_cnt'] / region_users['users_cnt'])*100
region_users.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_8dbfb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_cnt</th>        <th class="col_heading level0 col1" >payer_users_cnt</th>        <th class="col_heading level0 col2" >share</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8dbfb_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_8dbfb_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_8dbfb_row0_col1" class="data row0 col1" >6902</td>
#                         <td id="T_8dbfb_row0_col2" class="data row0 col2" >6.90%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Все пользователи находятся в 4 странах: США, Германия. Великобритания и Франция. Больше всего пользователей из США, а меньше всего - из Германии. В Великобритании и Франции примерно одинаковое число пользователей.
#
# Самая высокая доля платящих пользователей в США (6.90%), а самая низкая - во Франции (3,80%).
#
# ### Распределение пользователей по устройствам

# %%
device_users = pd.DataFrame()
device_users['users_cnt'] = profiles.groupby('device')['user_id'].count()
device_users['payer_users_cnt'] = profiles.query('payer == True').groupby('device')['user_id'].count()
device_users['share'] = (device_users['payer_users_cnt'] / device_users['users_cnt'])*100
device_users.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_f8c00_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_cnt</th>        <th class="col_heading level0 col1" >payer_users_cnt</th>        <th class="col_heading level0 col2" >share</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f8c00_level0_row0" class="row_heading level0 row0" >Mac</th>
#                         <td id="T_f8c00_row0_col0" class="data row0 col0" >30042</td>
#                         <td id="T_f8c00_row0_col1" class="data row0 col1" >1912</td>
#                         <td id="T_f8c00_row0_col2" class="data row0 col2" >6.36%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Больше всего пользователей приложения заходит в него и использует оплату с iPhone. Если же судить по доли платящих пользователей из всех, то она выше всего у пользователей Mac. Меньше всего платящие пользователи пользуются PC для доступа к приложению.
#
# ### Распределение пользователей по каналам

# %%
channel_users = pd.DataFrame()
channel_users['users_cnt'] = profiles.groupby('channel')['user_id'].count()
channel_users['payer_users_cnt'] = profiles.query('payer == True').groupby('channel')['user_id'].count()
channel_users['share'] = (channel_users['payer_users_cnt'] / channel_users['users_cnt'])*100
channel_users.sort_values(by='share', ascending=False).style.format({'share': '{:.1f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_e8967_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_cnt</th>        <th class="col_heading level0 col1" >payer_users_cnt</th>        <th class="col_heading level0 col2" >share</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8967_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#                         <td id="T_e8967_row0_col0" class="data row0 col0" >29144</td>
#                         <td id="T_e8967_row0_col1" class="data row0 col1" >3557</td>
#                         <td id="T_e8967_row0_col2" class="data row0 col2" >12.2%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Больше всего платящих пользователей как в абсолютном, так и в относительном исчислении приходит с FaceBoom. Больше всего пользователей приходит без привлечения конкретного канала, но среди них меньше всего доля платящих пользователй. Выделяется ещё канал TipTop, откуда пришёл 19561 пользователь. Доля платящих пользователей этого канала 9.60%. Хорошая конвертация в платящих пользователей происходит ещё через каналы AdNonSense и lambdaMediaAds.
#
# ## Маркетинг
#
# ### Расходы на маркетинг

# %%
costs.head() # выведем первые 5 строк таблицы costs
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs_sum = costs['costs'].sum().round() 
print('Сумма всех затрат на маркетинг:',costs_sum)
# Out:
# Сумма всех затрат на маркетинг: 105497.0

# %%
costs_channel = pd.DataFrame()
costs_channel['costs'] = costs.groupby('channel')['costs'].sum()
costs_channel['share'] = (costs_channel['costs'] / sum(costs_channel['costs']))*100
costs_channel.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_2b68f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >costs</th>        <th class="col_heading level0 col1" >share</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b68f_level0_row0" class="row_heading level0 row0" >TipTop</th>
#                         <td id="T_2b68f_row0_col0" class="data row0 col0" >54751.300000</td>
#                         <td id="T_2b68f_row0_col1" class="data row0 col1" >51.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_2b68f_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_2b68f_row1_col0" class="data row1 col0" >32445.600000</td>
# ...

# %% [markdown]
# Самым затратным является канал TipTop, далее идут FaceBoom и WahooNetBanner. Первые 2 канала забрали себе 80% бюджета. Меньше всего денег тратися на привлечения пользователей с канала YRabbit. Третьим с конца по затратм идёт канал lambdaMediaAds, доля платящих польователей откуда составляет 10,50%.
#
# ### Динамика затрат

# %%
cac_data = costs.pivot_table(
        index='dt', columns='channel', values='costs', aggfunc='sum'
    )
window = 5
filter_data(cac_data, window).plot(                                             
           figsize=(12, 10),
           grid=True,)
plt.title('График изменения затрат в разбивке по каналам')
plt.xlabel('Дата')
plt.ylabel('Затраты')
plt.show()

# %%
# создадим столбец с номером месяца и номером недели
costs['dt'] = pd.to_datetime(costs['dt'])
costs['month'] = costs['dt'].dt.month
costs['week'] = costs['dt'].dt.isocalendar().week

# %% [markdown]
# **Рассмотрим динамику по месяцам и по неделям**

# %%
costs.pivot_table(
    index='month',  
    columns='channel', 
    values='costs',  
    aggfunc='sum',  
).plot(figsize=(15, 10), grid=True, style='o-')

plt.title('Изменение трат по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Расходы')
plt.show()

# %%
costs.pivot_table(
    index='week',
    columns='channel',
    values='costs',  
    aggfunc='sum',  
).plot(figsize=(15, 10), grid=True, style='o-')

plt.title('Изменение трат по неделям')
plt.xlabel('Неделя')
plt.ylabel('Расходы')
plt.show()

# %% [markdown]
# Каналы TipTop и FaceBoom искажают динамику затртат на остальные каналы. Уберём их из выборки.

# %%
lower_costs = costs.query('channel != "FaceBoom" & channel != "TipTop"')
lower_costs.pivot_table(
    index='month', 
    columns='channel',
    values='costs',  
    aggfunc='sum',  
).plot(figsize=(15, 10), grid=True, style='o-')

plt.title('Изменение трат по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Расходы')
plt.show()

# %%
lower_costs.pivot_table(
    index='week',
    columns='channel',
    values='costs',  
    aggfunc='sum',  
).plot(figsize=(15, 10), grid=True, style='o-')

plt.title('Изменение трат по неделям')
plt.xlabel('Неделя')
plt.ylabel('Расходы')
plt.show()

# %% [markdown]
# Затраты на продвижение в каналах TipTop и FaceBoom сильно выше затрта на других каналах. Особенно сильно разница заметна с мая 2019 года, просадки наблюдаются в середине некоторых месяцев. По остальным каналам сильных скачков не наблюдается.
#
# Каждый месяц с мая по сентябрь расходы на рекламу росли все больше и больше. График изменения расходов  показал, что траты на TipTop возрастали с каждым месяцем большими темпами, а траты на FaceBoom росли гораздо медленнее. Все остальные источники существенно уступают по объему расходов на маркетинг.
#
# При более детальном рассмотрении можно отметить, что у WahooNetBanner затраты растут относительно других каналов, а у AdNonSense затраты немного сокращают.
#
# ### Стоимость привлечения одного пользователя

# %%
# CAC для каждого источника трафика
cac_by_channel = pd.DataFrame()
profiles_new = profiles.query('channel != "organic"')
cac_by_channel['acquisition_cost_mean'] = profiles_new.groupby('channel')['acquisition_costs'].mean()
cac_by_channel.sort_values(by='acquisition_cost_mean', ascending=False).style.format({'acquisition_cost_mean': '{:.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_87d4e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >acquisition_cost_mean</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87d4e_level0_row0" class="row_heading level0 row0" >TipTop</th>
#                         <td id="T_87d4e_row0_col0" class="data row0 col0" >2.80</td>
#             </tr>
#             <tr>
#                         <th id="T_87d4e_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_87d4e_row1_col0" class="data row1 col0" >1.11</td>
#             </tr>
#             <tr>
#                         <th id="T_87d4e_level0_row2" class="row_heading level0 row2" >AdNonSense</th>
#                         <td id="T_87d4e_row2_col0" class="data row2 col0" >1.01</td>
#             </tr>
# ...

# %%
# CAC для каждой страны
cac_by_channel = pd.DataFrame()
profiles_new = profiles.query('channel != "organic"')
cac_by_channel['acquisition_cost_mean'] = profiles_new.groupby('region')['acquisition_costs'].mean()
cac_by_channel.sort_values(by='acquisition_cost_mean', ascending=False).style.format({'acquisition_cost_mean': '{:.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_acd68_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >acquisition_cost_mean</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_acd68_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_acd68_row0_col0" class="data row0 col0" >1.47</td>
#             </tr>
#             <tr>
#                         <th id="T_acd68_level0_row1" class="row_heading level0 row1" >Germany</th>
#                         <td id="T_acd68_row1_col0" class="data row1 col0" >0.46</td>
#             </tr>
#             <tr>
#                         <th id="T_acd68_level0_row2" class="row_heading level0 row2" >France</th>
#                         <td id="T_acd68_row2_col0" class="data row2 col0" >0.46</td>
#             </tr>
# ...

# %%
# CAC для каждой страны
cac_by_channel = pd.DataFrame()
profiles_new = profiles.query('channel != "organic"')
cac_by_channel['acquisition_cost_mean'] = profiles_new.groupby('device')['acquisition_costs'].mean()
cac_by_channel.sort_values(by='acquisition_cost_mean', ascending=False).style.format({'acquisition_cost_mean': '{:.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_f34a0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >acquisition_cost_mean</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f34a0_level0_row0" class="row_heading level0 row0" >iPhone</th>
#                         <td id="T_f34a0_row0_col0" class="data row0 col0" >1.29</td>
#             </tr>
#             <tr>
#                         <th id="T_f34a0_level0_row1" class="row_heading level0 row1" >Mac</th>
#                         <td id="T_f34a0_row1_col0" class="data row1 col0" >1.29</td>
#             </tr>
#             <tr>
#                         <th id="T_f34a0_level0_row2" class="row_heading level0 row2" >Android</th>
#                         <td id="T_f34a0_row2_col0" class="data row2 col0" >1.03</td>
#             </tr>
# ...

# %% [markdown]
# Самыми дорогими трафиками вышли TipTop (2.80), FaceBoom (1.11), AdNonSense(1.01). Самый дорогой трафик пользователей пришёлся на США, на тех, кто пользуется iPhone и Mac.

# %%
profiles_new['acquisition_costs'].mean() # среднее затрат
# Out:
# 1.1274813239427588

# %%
CAC_general = profiles_new.query('channel != "TipTop"')
CAC_general['acquisition_costs'].mean() # среднее затрат без канала с завышенным значением
# Out:
# 0.6856826289049833

# %% [markdown]
# Канал TipTop слишком дорого обходится компании, затрты на привлечение пользователей через него лучше сократить. Рекомендуется обратить внимание на каналы LeapBob, MediaTornado, YRabbit, OppleCreativeMedia.
# ## Оценка окупаемости рекламы
# ### Окупаемость рекламы

# %%
horizon_days = 14
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_new, orders, observation_date, horizon_days
)

display(ltv_grouped)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)
# Out:
#            cohort_size       0.0       1.0       2.0       3.0       4.0  \
# cohort
# All users        86138  0.344835  0.435825  0.503889  0.560611  0.611611
#
#                 5.0       6.0       7.0       8.0       9.0      10.0  \
# cohort
# All users  0.654576  0.694741  0.730661  0.765474  0.797583  0.826827
#
#                11.0      12.0      13.0
# cohort
# All users  0.852804  0.878797  0.903117

# %% [markdown]
# LTV держится на примерно одном уровне на протяжении всего периода времени.
#
# CAC на протяжении всего периода времени растёт.
#
# ROI не доходит до уровня окупаемости.
#
# Пользователи перестают окупаться уже с июня.
# #### Окупаемость рекламы по странам

# %%
# смотрим окупаемость с разбивкой по странам
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_new, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Реклама для привлечения пользователей из США практически не окупается и сильно портит общую статистику. Несмотря на высокий LTV, стоимость привлечения пользователей постоянно растёт высокими темпами. Возможно, процесс закупки рекламы вышел из-под контроля.
#
# Привлекательнее всего выглядит окупаемость рекламы для пользователей из Великобритании.
#
# #### Окупаемость рекламы по каналам

# %%
# смотрим окупаемость с разбивкой по каналам
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_new, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %%
# исключение из таблицы всех стран, кроме США
profiles_USA = profiles_new.query('region == "United States"')

# смотрим окупаемость пользователей из США с разбивкой по каналам
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_USA, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %%
# исключение из таблицы всех стран, кроме США
other_profiles = profiles_new.query('region != "United States"')

# смотрим окупаемость с разбивкой по каналам
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    other_profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Как и говорилось ранее, пользователи с YRabbit хорошо окупают рекламу на своё привлечение, относительно других. Неплохие результаты у MediaTornado и lambdaMediaAds. С сентября виден потенциал у RocketSuperAds. Самые плохие результаты окупаемости у каналов TipTop, FaceBoom и AdNonSense.
#
# У канала TipTop рекламный бюджет улетает наверх. Вероятно, процесс закупки рекламы вышел из-под контроля.
#
# Исходя из анализа аудитории только из США, проблемы с окупаемостью можно связать именно с пользователями с каналов TipTop и FaceBoom. В остальных странах все каналы, кроме AdNonSense окупаются.
#
# #### Окупаемость рекламы по устройствам

# %%
# смотрим окупаемость с разбивкой по устройствам
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_new, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %%
# смотрим окупаемость пользователей из США с разбивкой по устройствам
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_USA, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %%
# смотрим окупаемость с разбивкой по источникам привлечения
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    other_profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Лучше всего окупаемость рекламы по пользователям, пользующимся PC и Android. Но,если брать пользователй из США, то они не окупились ни с одного устройства. Пользователи из других стран окупаются, причём очень хорошо с PC, но есть просадки у пользователей iPhone.
#
# ### Конверсия пользователей
# #### Конверия пользователей по устройствам

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_new, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Выше всего показатель конверсии у пользователей Mac и iPhone, а ниже всего - PC.
#
# #### Конверсия пользователей по странам

# %%
dimensions = ['region']
# смотрим конверсию с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_new, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи в США намного показывают высокую конверсию, по сравнению с пользователями из других стран. У пользователей из Франции этот показатель ниже всех.
#
# #### Конверсия пользователей по каналам

# %%
dimensions = ['channel']
# смотрим конверсию с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_new, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
dimensions = ['channel']
# смотрим конверсию пользователей из США с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_USA, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
dimensions = ['channel']
# смотрим конверсию европейских пользователей с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    other_profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия выше всего у пользователей, пришедших с рекламы на FaceBomm, AdNonSence и lambdaMediaAds. У тех, кто присоединился к приложению самостоятельно, конверсия очень низкая.
#
# ### Удержание пользователей
# #### Удержание пользователей по устройствам

# %%
# смотрим удержание с разбивкой по устройствам
dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles_new, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Динамика удержания неплатящих пользователей примерно одинаковая, независимо от устройства. Среди пользователей, приносящих деньги, лучше всего удерживаются пользователи PC.
#
# #### Удержание пользователей по странам

# %%
# смотрим удержание с разбивкой по странам
dimensions = ['region']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles_new, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Динамика удержания неплатящих пользователей примерно одинаковая, независимо от страны. Среди пользователей, приносящих деньги, хуже всех удерживаются пользователи из США.
# #### Удержание пользователей по каналам

# %%
# смотрим удержание с разбивкой по каналам
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles_new, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
# смотрим удержание пользователей из США с разбивкой по каналам
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles_USA, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
# смотрим удержание европейских пользователей с разбивкой по каналам
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    other_profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Динамика удержания неплатящих пользователей примерно одинаковая, независимо от страны. Среди пользователей, приносящих деньги, хуже всех удерживаются пользователи с FaceBoom и AdNonSence.

# %% [markdown]
# ## Выводы
#
# - В результате удалось выяснить, что реклама не окупается в некоторых случаях.
# - Негативное влияние на окупаемость оказывают пользователи из США, привлечённые с помощью TipTop, FaceBoom, и пользователи из других стран, привлечённые с помощью AdNonSense.
# - Проблемы с окупаемостью могут быть вызваны неправильным распределением средств на привлечение с каналов.
#
# Возможные причины, связанные с проблемой рекламы:
#
# * рекламная система AdNonSense оказалась не такой эффективной во всех странах, кроме США, как ожидалось; канал переоценён или настроен неправильно;
# * рекламная система TipTop и и FaceBoom оказалась не такой эффективной в США, как ожидалось; каналы переоценены или настроены неправильно;
# * на определение страны пользователей могло повлиять использование VPN.

# %% [markdown]
# <div style="border:solid black 2px; padding: 10px">
#
# **Рекомендации🤗**
#
#     1) TipTop и FaceBoom являются наиболее расходными каналами в США. Нужно проверить распределение бюджета на рекламу на этих каналах. Возможно, установлены неправильные настройки. Бюджет по ним необходимо сократить.
#
#     2) Пользователи с канала AdNonSense портят статистику окупаемости рекламы в европейских странах, но хорошо удерживаются и показывают высокую конверсию. На графике видно, что стоимость привлечения пользователей в этом регионе относительно высокая, что мешает окупаемости.
#
#     3) Среди пользователей, приносящих деньги, хуже всех удерживаются пользователи с FaceBoom и AdNonSence. Несмотря на высокую конверсию, показатели удержания и окупаемости склоняют сократить бюджет этих каналов. Против них также и показатель расходов на привлечение одного пользователя, тк каналы в тройке лидеров по высоте этого показателя.
#
#     4) Платящие PC пользователи удерживаются очень хорошо, но конверсия самая низкая. Вероятно, как и с окупаемостью, проблемы именно с американской аудиторией, которая держится именно на бесплатном контенте.
#
#     5) Можно выделить следующие удачные каналы для привлечения клиентов: WahooNetBanner и lambdaMediaAds для европейских пользователей и с RocketSuperAds для американских пользователей.
